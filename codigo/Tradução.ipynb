# %% [markdown]
# **Inicialização**

# %%
import pandas as pd
import numpy as np

# %%
# removendo máximo numero de colunas e linhas em display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# importa os dados em inglês
ames_housing = pd.read_csv("../outputs/ames housing.csv")
ames_housing.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
# imprime as categorias de cada dado categorico
categorical_cols = ames_housing.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    print(f"{col}:\n {ames_housing[col].unique()} \n")
# Out:
# MS Zoning:
#  ['RL' 'RH' 'FV' 'RM' 'C (all)' 'I (all)' 'A (agr)']
#
# Street:
#  ['Pave' 'Grvl']
#
# Alley:
#  [nan 'Pave' 'Grvl']
#
# Lot Shape:
#  ['IR1' 'Reg' 'IR2' 'IR3']
#
# Land Contour:
#  ['Lvl' 'HLS' 'Bnk' 'Low']
#
# Utilities:
#  ['AllPub' 'NoSewr' 'NoSeWa']
#
# Lot Config:
#  ['Corner' 'Inside' 'CulDSac' 'FR2' 'FR3']
#
# Land Slope:
#  ['Gtl' 'Mod' 'Sev']
#
# Neighborhood:
#  ['NAmes' 'Gilbert' 'StoneBr' 'NWAmes' 'Somerst' 'BrDale' 'NPkVill'
#  'NridgHt' 'Blmngtn' 'NoRidge' 'SawyerW' 'Sawyer' 'Greens' 'BrkSide'
#  'OldTown' 'IDOTRR' 'ClearCr' 'SWISU' 'Edwards' 'CollgCr' 'Crawfor'
#  'Blueste' 'Mitchel' 'Timber' 'MeadowV' 'Veenker' 'GrnHill' 'Landmrk']
#
# Condition 1:
#  ['Norm' 'Feedr' 'PosN' 'RRNe' 'RRAe' 'Artery' 'PosA' 'RRAn' 'RRNn']
#
# Condition 2:
#  ['Norm' 'Feedr' 'PosA' 'PosN' 'Artery' 'RRNn' 'RRAe' 'RRAn']
#
# Bldg Type:
#  ['1Fam' 'TwnhsE' 'Twnhs' 'Duplex' '2fmCon']
#
# House Style:
#  ['1Story' '2Story' '1.5Fin' 'SFoyer' 'SLvl' '2.5Unf' '1.5Unf' '2.5Fin']
#
# ...

# %% [markdown]
# **Tradução do nome dos atributos**

# %%
attribute_name_translation_map = {
    "Order": "Índice",
    "PID": "Identificação da Propriedade",
    "MS SubClass": "Classe de Subdivisão",
    "MS Zoning": "Zoneamento Municipal",
    "Lot Frontage": "Frente do Lote",
    "Lot Area": "Área do Lote",
    "Street": "Rua",
    "Alley": "Beco",
    "Lot Shape": "Forma do Lote",
    "Land Contour": "Contorno do Terreno",
    "Utilities": "Utilidades",
    "Lot Config": "Configuração do Lote",
    "Land Slope": "Declive do Terreno",
    "Neighborhood": "Vizinhança",
    "Condition 1": "Condição 1",
    "Condition 2": "Condição 2",
    "Bldg Type": "Tipo de Edifício",
    "House Style": "Estilo da Casa",
    "Overall Qual": "Qualidade Geral",
    "Overall Cond": "Condição Geral",
    "Year Built": "Ano de Construção",
    "Year Remod/Add": "Ano de Reforma ou Adição",
    "Roof Style": "Estilo do Telhado",
    "Roof Matl": "Material do Telhado",
    "Exterior 1st": "Exterior 1",
    "Exterior 2nd": "Exterior 2",
    "Mas Vnr Type": "Tipo de Revestimento de Alvenaria",
    "Mas Vnr Area": "Área de Revestimento de Alvenaria",
    "Exter Qual": "Qualidade Exterior",
    "Exter Cond": "Condição Exterior",
    "Foundation": "Fundação",
    "Bsmt Qual": "Qualidade do Porão",
    "Bsmt Cond": "Condição do Porão",
    "Bsmt Exposure": "Exposição do Porão",
    "BsmtFin Type 1": "Tipo de Acabamento do Porão 1",
    "BsmtFin SF 1": "Área de Acabamento do Porão 1",
    "BsmtFin Type 2": "Tipo de Acabamento do Porão 2",
    "BsmtFin SF 2": "Área de Acabamento do Porão 2",
    "Bsmt Unf SF": "Área Não Acabada do Porão",
    "Total Bsmt SF": "Área Total do Porão",
    "Heating": "Aquecimento",
    "Heating QC": "Qualidade do Aquecimento",
    "Central Air": "Ar Condicionado Central",
    "Electrical": "Elétrica",
    "1st Flr SF": "Área do Primeiro Andar",
    "2nd Flr SF": "Área do Segundo Andar",
    "Low Qual Fin SF": "Área de Baixa Qualidade",
    "Gr Liv Area": "Área Habitável Total",
    "Bsmt Full Bath": "Banheiros Completos no Porão",
    "Bsmt Half Bath": "Banheiros Meio no Porão",
    "Full Bath": "Banheiros Completos",
    "Half Bath": "Banheiros Meio",
    "Bedroom AbvGr": "Quartos Acima do Solo",
    "Kitchen AbvGr": "Cozinhas Acima do Solo",
    "Kitchen Qual": "Qualidade da Cozinha",
    "TotRms AbvGrd": "Total de Quartos Acima do Solo",
    "Functional": "Funcionalidade",
    "Fireplaces": "Lareiras",
    "Fireplace Qu": "Qualidade da Lareira",
    "Garage Type": "Tipo de Garagem",
    "Garage Yr Blt": "Ano de Construção da Garagem",
    "Garage Finish": "Acabamento da Garagem",
    "Garage Cars": "Carros na Garagem",
    "Garage Area": "Área da Garagem",
    "Garage Qual": "Qualidade da Garagem",
    "Garage Cond": "Condição da Garagem",
    "Paved Drive": "Entrada Pavimentada",
    "Wood Deck SF": "Área do Deck de Madeira",
    "Open Porch SF": "Área da Varanda Aberta",
    "Enclosed Porch": "Área da Varanda Fechada",
    "3Ssn Porch": "Área da Varanda de 3 Estações",
    "Screen Porch": "Área da Varanda Telada",
    "Pool Area": "Área da Piscina",
    "Pool QC": "Qualidade da Piscina",
    "Fence": "Cerca",
    "Misc Feature": "Características Diversas",
    "Misc Val": "Valor das Características Diversas",
    "Mo Sold": "Mês de Venda",
    "Yr Sold": "Ano de Venda",
    "Sale Type": "Tipo de Venda",
    "Sale Condition": "Condição de Venda",
    "SalePrice": "Preço de Venda"
}

casas_em_ames = ames_housing.rename(attribute_name_translation_map, axis = 1)
casas_em_ames.head()
# Out:
#    Índice  Identificação da Propriedade  Classe de Subdivisão  \
# 0       1                     526301100                    20
# 1       2                     526350040                    20
# 2       3                     526351010                    20
# 3       4                     526353030                    20
# 4       5                     527105010                    60
#
#   Zoneamento Municipal  Frente do Lote  Área do Lote   Rua Beco Forma do Lote  \
# 0                   RL           141.0         31770  Pave  NaN           IR1
# 1                   RH            80.0         11622  Pave  NaN           Reg
# 2                   RL            81.0         14267  Pave  NaN           IR1
# 3                   RL            93.0         11160  Pave  NaN           Reg
# 4                   RL            74.0         13830  Pave  NaN           IR1
#
#   Contorno do Terreno Utilidades Configuração do Lote Declive do Terreno  \
# ...

# %% [markdown]
# **Tradução das categorias de atributos categoricos**

# %%
ms_zoning_translation_map = {
    'RM': 'Residencial Média Densidade',
    'A (agr)': 'Agrícola',
    'RL': 'Residencial Baixa Densidade',
    'C (all)': 'Comercial',
    'I (all)': 'Industrial',
    'RH': 'Residencial Alta Densidade',
    'FV': 'Residencial Flutuante'
}

street_translation_map = {
    'Grvl': 'Cascalho',
    'Pave': 'Pavimentado'
}

alley_translation_map = {
    'Grvl': 'Cascalho',
    'Pave': 'Pavimentado'
}

lot_shape_translation_map = {
    'Reg': 'Regular',
    'IR1': 'Irregular 1',
    'IR2': 'Irregular 2',
    'IR3': 'Irregular 3'
}

land_contour_translation_map = {
    'Lvl': 'Plano',
    'HLS': 'Declive Suave',
    'Bnk': 'Terreno Inclinado',
    'Low': 'Baixo'
}

utilities_translation_map = {
    'AllPub': 'Todas as Utilidades Públicas',
    'NoSeWa': 'Sem Esgoto e Água',
    'NoSewr': 'Sem Esgoto'
}

lot_config_translation_map = {
    'Inside': 'Interior',
    'FR2': 'Frente 2',
    'FR3': 'Frente 3',
    'Corner': 'Esquina',
    'CulDSac': 'Cul-de-sac'
}

land_slope_translation_map = {
    'Gtl': 'Leve',
    'Mod': 'Moderado',
    'Sev': 'Severo'
}

neighborhood_translation_map = {
    'Timber': 'Madeira',
    'Crawfor': 'Crawford',
    'Mitchel': 'Mitchel',
    'Blmngtn': 'Bloomington',
    'SawyerW': 'Sawyer Oeste',
    'SWISU': 'SWISU',
    'OldTown': 'Cidade Antiga',
    'NWAmes': 'NW Ames',
    'Sawyer': 'Sawyer',
    'Veenker': 'Veenker',
    'NridgHt': 'North Ridge Heights',
    'Gilbert': 'Gilbert',
    'GrnHill': 'Colina Verde',
    'StoneBr': 'Stone Brook',
    'BrkSide': 'Brook Side',
    'CollgCr': 'College Creek',
    'Blueste': 'Blue Stone',
    'NPkVill': 'North Park Villa',
    'IDOTRR': 'IDOTRR',
    'NAmes': 'North Ames',
    'BrDale': 'Briar Dale',
    'MeadowV': 'Meadow Village',
    'Edwards': 'Edwards',
    'Greens': 'Greens',
    'Landmrk': 'Landmark',
    'Somerst': 'Somerset',
    'ClearCr': 'Clear Creek',
    'NoRidge': 'North Ridge'
}

condition1_translation_map = {
    'Norm': 'Normal',
    'RRAn': 'Adjacente a Ferrovia',
    'RRAe': 'Adjacente a Ferrovia (Estrada Elevada)',
    'Artery': 'Arterial',
    'Feedr': 'Alimentador',
    'PosN': 'Próximo a Parque (Negativo)',
    'PosA': 'Próximo a Parque (Positivo)',
    'RRNe': 'Adjacente a Ferrovia (Estrada Não Elevada)',
    'RRNn': 'Adjacente a Ferrovia (Estrada Não Elevada e Ruim)'
}

condition2_translation_map = {
    'Norm': 'Normal',
    'RRAn': 'Adjacente a Ferrovia',
    'RRAe': 'Adjacente a Ferrovia (Estrada Elevada)',
    'Artery': 'Arterial',
    'Feedr': 'Alimentador',
    'PosN': 'Próximo a Parque (Negativo)',
    'PosA': 'Próximo a Parque (Positivo)',
    'RRNn': 'Adjacente a Ferrovia (Estrada Não Elevada e Ruim)'
}


bldg_type_translation_map = {
    'Twnhs': 'Casa Geminada',
    '2fmCon': 'Casa de Família Dupla (Condomínio)',
    'TwnhsE': 'Casa Geminada (Extremidade)',
    'Duplex': 'Duplex',
    '1Fam': 'Casa Unifamiliar'
}

house_style_translation_map = {
    '1Story': '1 Andar',
    'SFoyer': 'Sótão',
    '1.5Unf': '1.5 Andares (Sem Acabamento)',
    '2Story': '2 Andares',
    'SLvl': 'Split Level',
    '1.5Fin': '1.5 Andares (Acabado)',
    '2.5Unf': '2.5 Andares (Sem Acabamento)',
    '2.5Fin': '2.5 Andares (Acabado)'
}

roof_style_translation_map = {
    'Gambrel': 'Gambrel',
    'Flat': 'Plano',
    'Hip': 'Hip',
    'Shed': 'Shed',
    'Gable': 'Gable',
    'Mansard': 'Mansard'
}

roof_matl_translation_map = {
    'CompShg': 'Telha Composta',
    'ClyTile': 'Telha de Argila',
    'WdShngl': 'Telha de Madeira',
    'Tar&Grv': 'Piche e Cascalho',
    'Metal': 'Metal',
    'WdShake': 'Madeira Agitada',
    'Roll': 'Rolo',
    'Membran': 'Membrana'
}

exterior1st_translation_map = {
    'MetalSd': 'Revestimento de Metal',
    'CBlock': 'Bloco de Concreto',
    'WdShing': 'Revestimento de Madeira',
    'Stone': 'Pedra',
    'Plywood': 'Contraplacado',
    'ImStucc': 'Estuque Imitado',
    'Stucco': 'Estuque',
    'HdBoard': 'Placa de Madeira',
    'AsphShn': 'Revestimento de Asfalto',
    'CemntBd': 'Placa de Cimento',
    'AsbShng': 'Revestimento de Amianto',
    'Wd Sdng': 'Revestimento de Madeira',
    'PreCast': 'Pré-moldado',
    'BrkComm': 'Tijolo Comum',
    'VinylSd': 'Revestimento de Vinil',
    'BrkFace': 'Tijolo à Vista'
}

exterior2nd_translation_map = {
    'MetalSd': 'Revestimento de Metal',
    'CBlock': 'Bloco de Concreto',
    'Stone': 'Pedra',
    'Plywood': 'Contraplacado',
    'CmentBd': 'Placa de Cimento',
    'ImStucc': 'Estuque Imitado',
    'Brk Cmn': 'Tijolo Comum',
    'Wd Shng': 'Revestimento de Madeira',
    'Stucco': 'Estuque',
    'HdBoard': 'Placa de Madeira',
    'AsphShn': 'Revestimento de Asfalto',
    'PreCast': 'Pré-moldado',
    'AsbShng': 'Revestimento de Amianto',
    'Wd Sdng': 'Revestimento de Madeira',
    'Other': 'Outro',
    'VinylSd': 'Revestimento de Vinil',
    'BrkFace': 'Tijolo à Vista'
}

mas_vnr_type_translation_map = {
    'CBlock': 'Bloco de Concreto',
    'Stone': 'Pedra',
    'BrkCmn': 'Tijolo Comum',
    'BrkFace': 'Tijolo à Vista'
}

exter_qual_translation_map = {
    'Fa': 'Ruim',
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média'
}

exter_cond_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

foundation_translation_map = {
    'CBlock': 'Bloco de Concreto',
    'PConc': 'Concreto Pré-moldado',
    'Stone': 'Pedra',
    'BrkTil': 'Tijolo',
    'Slab': 'Laje',
    'Wood': 'Madeira'
}

bsmt_qual_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

bsmt_cond_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

bsmt_exposure_translation_map = {
    'Gd': 'Boa',
    'Mn': 'Mínima',
    'Av': 'Média',
    'No': 'Nenhum'
}

bsmtfin_type1_translation_map = {
    'Unf': 'Sem Acabamento',
    'LwQ': 'Baixa Qualidade',
    'BLQ': 'Acabamento de Baixa Qualidade',
    'ALQ': 'Acabamento de Qualidade Média',
    'GLQ': 'Acabamento de Alta Qualidade',
    'Rec': 'Recreacional'
}

bsmtfin_type2_translation_map = {
    'Unf': 'Sem Acabamento',
    'LwQ': 'Baixa Qualidade',
    'BLQ': 'Acabamento de Baixa Qualidade',
    'ALQ': 'Acabamento de Qualidade Média',
    'GLQ': 'Acabamento de Alta Qualidade',
    'Rec': 'Recreacional'
}

heating_translation_map = {
    'Wall': 'Parede',
    'Floor': 'Piso',
    'GasA': 'Gás Ar',
    'OthW': 'Outro',
    'Grav': 'Gravidade',
    'GasW': 'Gás Líquido'
}

heating_qc_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

central_air_translation_map = {
    'Y': 'Sim',
    'N': 'Não'
}

electrical_translation_map = {
    'FuseA': 'Fusível A',
    'FuseP': 'Fusível P',
    'FuseF': 'Fusível F',
    'Mix': 'Misto',
    'SBrkr': 'Disjuntores'
}

kitchen_qual_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

functional_translation_map = {
    'Typ': 'Típico',
    'Mod': 'Moderado',
    'Min1': 'Reformas Menores 1',
    'Min2': 'Reformas Menores 2',
    'Maj1': 'Reformas Maiores 1',
    'Maj2': 'Reformas Maiores 2',
    'Sev': 'Severo',
    'Sal': 'Apenas Resgate'
}

fireplace_qu_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

garage_type_translation_map = {
    'Basment': 'Garagem no Porão',
    'Detchd': 'Garagem Separada',
    '2Types': 'Dois Tipos',
    'Attchd': 'Garagem Anexa',
    'CarPort': 'CarPort',
    'BuiltIn': 'Garagem Embutida'
}

garage_finish_translation_map = {
    'Unf': 'Inacabado',
    'Fin': 'Acabada',
    'RFn': 'Acabamento Rústico'
}

garage_qual_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

garage_cond_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim',
    'Po': 'Pobre'
}

paved_drive_translation_map = {
    'Y': 'Sim',
    'N': 'Não',
    'P': 'Parcial'
}

pool_qc_translation_map = {
    'Gd': 'Boa',
    'Ex': 'Excelente',
    'TA': 'Média',
    'Fa': 'Ruim'
}

fence_translation_map = {
    'GdWo': 'Boa Madeira',
    'GdPrv': 'Boa Privacidade',
    'MnPrv': 'Privacidade Média',
    'MnWw': 'Madeira Média'
}

misc_feature_translation_map = {
    'Elev': 'Elevador',
    'Othr': 'Outros',
    'TenC': 'Quadra de Tênis',
    'Shed': 'Galpão',
    'Gar2': 'Segunda Garagem'
}

sale_type_translation_map = {
    'ConLI': 'Contrato de Venda com Acréscimo de Juro',
    'ConLw': 'Contrato de Venda com Acréscimo de Juro Baixo',
    'Con': 'Contrato de Venda',
    'WD ': 'Garantia de Renúncia',
    'ConLD': 'Contrato de Venda com Acréscimo de Juro Diferido',
    'COD': 'Contrato por Deficiência',
    'CWD': 'Garantia de Renúncia Certificada',
    'VWD': 'Garantia de Renúncia de Revenda',
    'New': 'Novo',
    'Oth': 'Outro'
}

sale_condition_translation_map = {
    'AdjLand': 'Venda de Terreno Adjacente',
    'Family': 'Venda entre Familiares',
    'Alloca': 'Alocação',
    'Partial': 'Parcial',
    'Abnorml': 'Venda Anormal',
    'Normal': 'Normal'
}

# %%
casas_em_ames['Zoneamento Municipal'] = casas_em_ames['Zoneamento Municipal'].map(ms_zoning_translation_map)
casas_em_ames['Rua'] = casas_em_ames['Rua'].map(street_translation_map)
casas_em_ames['Beco'] = casas_em_ames['Beco'].map(alley_translation_map)
casas_em_ames['Forma do Lote'] = casas_em_ames['Forma do Lote'].map(lot_shape_translation_map)
casas_em_ames['Contorno do Terreno'] = casas_em_ames['Contorno do Terreno'].map(land_contour_translation_map)
casas_em_ames['Utilidades'] = casas_em_ames['Utilidades'].map(utilities_translation_map)
casas_em_ames['Configuração do Lote'] = casas_em_ames['Configuração do Lote'].map(lot_config_translation_map)
casas_em_ames['Declive do Terreno'] = casas_em_ames['Declive do Terreno'].map(land_slope_translation_map)
casas_em_ames['Vizinhança'] = casas_em_ames['Vizinhança'].map(neighborhood_translation_map)
casas_em_ames['Condição 1'] = casas_em_ames['Condição 1'].map(condition1_translation_map)
casas_em_ames['Condição 2'] = casas_em_ames['Condição 2'].map(condition2_translation_map)
casas_em_ames['Tipo de Edifício'] = casas_em_ames['Tipo de Edifício'].map(bldg_type_translation_map)
casas_em_ames['Estilo da Casa'] = casas_em_ames['Estilo da Casa'].map(house_style_translation_map)
casas_em_ames['Estilo do Telhado'] = casas_em_ames['Estilo do Telhado'].map(roof_style_translation_map)
casas_em_ames['Material do Telhado'] = casas_em_ames['Material do Telhado'].map(roof_matl_translation_map)
casas_em_ames['Exterior 1'] = casas_em_ames['Exterior 1'].map(exterior1st_translation_map)
casas_em_ames['Exterior 2'] = casas_em_ames['Exterior 2'].map(exterior2nd_translation_map)
casas_em_ames['Tipo de Revestimento de Alvenaria'] = casas_em_ames['Tipo de Revestimento de Alvenaria'].map(mas_vnr_type_translation_map)
casas_em_ames['Qualidade Exterior'] = casas_em_ames['Qualidade Exterior'].map(exter_qual_translation_map)
casas_em_ames['Condição Exterior'] = casas_em_ames['Condição Exterior'].map(exter_cond_translation_map)
casas_em_ames['Fundação'] = casas_em_ames['Fundação'].map(foundation_translation_map)
casas_em_ames['Qualidade do Porão'] = casas_em_ames['Qualidade do Porão'].map(bsmt_qual_translation_map)
casas_em_ames['Condição do Porão'] = casas_em_ames['Condição do Porão'].map(bsmt_cond_translation_map)
casas_em_ames['Exposição do Porão'] = casas_em_ames['Exposição do Porão'].map(bsmt_exposure_translation_map)
casas_em_ames['Tipo de Acabamento do Porão 1'] = casas_em_ames['Tipo de Acabamento do Porão 1'].map(bsmtfin_type1_translation_map)
casas_em_ames['Tipo de Acabamento do Porão 2'] = casas_em_ames['Tipo de Acabamento do Porão 2'].map(bsmtfin_type2_translation_map)
casas_em_ames['Aquecimento'] = casas_em_ames['Aquecimento'].map(heating_translation_map)
casas_em_ames['Qualidade do Aquecimento'] = casas_em_ames['Qualidade do Aquecimento'].map(heating_qc_translation_map)
casas_em_ames['Ar Condicionado Central'] = casas_em_ames['Ar Condicionado Central'].map(central_air_translation_map)
casas_em_ames['Elétrica'] = casas_em_ames['Elétrica'].map(electrical_translation_map)
casas_em_ames['Qualidade da Cozinha'] = casas_em_ames['Qualidade da Cozinha'].map(kitchen_qual_translation_map)
casas_em_ames['Funcionalidade'] = casas_em_ames['Funcionalidade'].map(functional_translation_map)
casas_em_ames['Qualidade da Lareira'] = casas_em_ames['Qualidade da Lareira'].map(fireplace_qu_translation_map)
casas_em_ames['Tipo de Garagem'] = casas_em_ames['Tipo de Garagem'].map(garage_type_translation_map)
casas_em_ames['Acabamento da Garagem'] = casas_em_ames['Acabamento da Garagem'].map(garage_finish_translation_map)
casas_em_ames['Qualidade da Garagem'] = casas_em_ames['Qualidade da Garagem'].map(garage_qual_translation_map)
casas_em_ames['Condição da Garagem'] = casas_em_ames['Condição da Garagem'].map(garage_cond_translation_map)
casas_em_ames['Entrada Pavimentada'] = casas_em_ames['Entrada Pavimentada'].map(paved_drive_translation_map)
casas_em_ames['Qualidade da Piscina'] = casas_em_ames['Qualidade da Piscina'].map(pool_qc_translation_map)
casas_em_ames['Cerca'] = casas_em_ames['Cerca'].map(fence_translation_map)
casas_em_ames['Características Diversas'] = casas_em_ames['Características Diversas'].map(misc_feature_translation_map)
casas_em_ames['Tipo de Venda'] = casas_em_ames['Tipo de Venda'].map(sale_type_translation_map)
casas_em_ames['Condição de Venda'] = casas_em_ames['Condição de Venda'].map(sale_condition_translation_map)

casas_em_ames.head()
# Out:
#    Índice  Identificação da Propriedade  Classe de Subdivisão  \
# 0       1                     526301100                    20
# 1       2                     526350040                    20
# 2       3                     526351010                    20
# 3       4                     526353030                    20
# 4       5                     527105010                    60
#
#           Zoneamento Municipal  Frente do Lote  Área do Lote          Rua  \
# 0  Residencial Baixa Densidade           141.0         31770  Pavimentado
# 1   Residencial Alta Densidade            80.0         11622  Pavimentado
# 2  Residencial Baixa Densidade            81.0         14267  Pavimentado
# 3  Residencial Baixa Densidade            93.0         11160  Pavimentado
# 4  Residencial Baixa Densidade            74.0         13830  Pavimentado
#
#   Beco Forma do Lote Contorno do Terreno                    Utilidades  \
# 0  NaN   Irregular 1               Plano  Todas as Utilidades Públicas
# ...

# %% [markdown]
# **Salvando tradução**

# %%
casas_em_ames.to_csv("../outputs/casas em ames.csv", index = False)
